# %% [markdown]
# <a href="https://colab.research.google.com/github/47v0/cs4782-final-project/blob/main/data/data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/47v0/cs4782-final-project
# Out:
# Cloning into 'cs4782-final-project'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 6 (delta 1), reused 5 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (6/6), done.
# Resolving deltas: 100% (1/1), done.
